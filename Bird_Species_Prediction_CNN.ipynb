# %% [markdown]
# # Bird Species Prediction

# %% [markdown]
# In this project we will create a Convolutional Neural Network which will be able to predict species of the bird. We will use different layers and other hyperparameters for building, training and testing this multiclass classifictaion model. We will be using keras for this project.

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# First we will mount our google drive on colab so that we can use the dataset directly from our drive. For this you first need to upload the data on your drive and then mount the drive on colab.

# %%
# After executing the cell above, Drive files will be present in "/content/drive/My Drive".
# !ls "/content/drive/My Drive"
# Out:
# '14MCA011 Avinash Gaikwad.pptx'		  'Bird Speciees Dataset'      Paymen_Screenshot.jpeg
#  911.csv				   Cat_vs_Dog		       Screenshort.jpeg
#  AvinashG.pdf				  'Colab Notebooks'	       Screenshot_2022-06-01.jpg
# 'AvinashG_Python_Developer (1) (1).docx'   Final_nihilent_folder.zip   Screenshot.jpeg
# 'AvinashG_Python_Developer (1).docx'	   movies_complete.csv	       Solution1.rar
# 'Avinash Prakash Gaikwad.jpg'		  'My Drive'		       yolov3

# %% [markdown]
# After mounting our drive we will locate the folder where our data is stored to use it in our colab notebook. Here you can see that all the folders I have in my drive and 'Bird Species Dataset' contains the images that we will work on.

# %%
# Library imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
from os import listdir
from sklearn.preprocessing import  LabelBinarizer
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array, array_to_img
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense
from sklearn.model_selection import train_test_split

# %% [markdown]
# We will start by importing some required libraries.

# %%
# Plotting 12 images to check dataset
plt.figure(figsize=(12,12))
path = "/content/drive/MyDrive/Bird Speciees Dataset/AMERICAN GOLDFINCH"
for i in range(1,17):
    plt.subplot(4,4,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(listdir(path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10)
    plt.ylabel(rand_img.shape[0], fontsize = 10)

# %% [markdown]
# Let's visualize some of the bird images that we will be working on. Also we will observe x and y dimensions of the image.

# %%
# Setting path and creating empty list
dir = "/content/drive/MyDrive/Bird Speciees Dataset"
root_dir = listdir(dir)
image_list, label_list = [], []

# %% [markdown]
# Setting the root directory for the dataset and storing all the floders name of the dataset. We will also create 2 empty list for image and lables.

# %%
# Reading and converting image to numpy array
for directory in root_dir:
  for files in listdir(f"{dir}/{directory}"):
    image_path = f"{dir}/{directory}/{files}"
    image = cv2.imread(image_path)
    image = img_to_array(image)
    image_list.append(image)
    label_list.append(directory)

# %% [markdown]
# Next we will read all the images and convert it into array and appending the list created above with the image and its label.

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts
# Out:
# AMERICAN GOLDFINCH    143
# EMPEROR PENGUIN       139
# DOWNY WOODPECKER      137
# FLAMINGO              132
# CARMINE BEE-EATER     131
# BARN OWL              129
# Name: count, dtype: int64

# %% [markdown]
# Check for class imbalance.

# %%
# Storing number of classes
num_classes = len(label_counts)
num_classes
# Out:
# 6

# %% [markdown]
# Next we will find out the number of classes that we will be working on.

# %%
# Checking input image shape
image_list[0].shape
# Out:
# (224, 224, 3)

# %% [markdown]
# Checking the size of the single image.

# %%
# Checking labels shape
label_list = np.array(label_list)
label_list.shape
# Out:
# (811,)

# %% [markdown]
# Checking the shape of image labels which will be equal to the number of images we are going to work with.

# %%
# Splitting dataset
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %% [markdown]
# Now we will split the data into training and testing using train_test_split() of sklearn.

# %%
# Normalize and reshape data
x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape( -1, 224,224,3)
x_test = x_test.reshape( -1, 224,224,3)

# %% [markdown]
# Next we will normalize the images by dividing them with 255. Also, we will reshape x_train and x_test.

# %%
# Label binarizing
lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.fit_transform(y_test)
print(lb.classes_)
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER'
#  'EMPEROR PENGUIN' 'FLAMINGO']

# %% [markdown]
# Next we will use label binarizer to one hot encode our y data. We will also print the sequence of the classes.

# %%
# Splitting the training data set into training and validation data sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %% [markdown]
# Now we will split the training data to validation and training data.

# %%
# Building model architecture
model = Sequential()
model.add(Conv2D(8, (3, 3), padding="same",input_shape=(224,224,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(32, activation="relu"))
model.add(Dense(num_classes, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 8)       224
#
#  max_pooling2d (MaxPooling2  (None, 74, 74, 8)         0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 74, 74, 16)        1168
#
#  max_pooling2d_1 (MaxPoolin  (None, 37, 37, 16)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 37, 37, 32)        4640
#
#  max_pooling2d_2 (MaxPoolin  (None, 18, 18, 32)        0
#  g2D)
#
#  flatten (Flatten)           (None, 10368)             0
#
#  dense (Dense)               (None, 32)                331808
#
#  dense_1 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 338038 (1.29 MB)
# Trainable params: 338038 (1.29 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Next we will create a network architecture for the model. We have used different types of layers according to their features namely Conv_2d (It is used to create a convolutional kernel that is convolved with the input layer to produce the output tensor), max_pooling2d (It is a downsampling technique which takes out the maximum value over the window defined by poolsize), flatten (It flattens the input and creates a 1D output), Dense (Dense layer produce the output as the dot product of input and kernel). In the last layer we will use softmax as the activation function because it is a multi class classification problem.

# %%
# Compiling model
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0005),metrics=['accuracy'])

# %% [markdown]
# While compiling the model we need to set the type of loss which will be Categorical Crossentropy for our model alongwith this we also need to set the optimizer and the metrics respectively.

# %%
# Training the model
epochs = 50
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 7s 272ms/step - loss: 1.7545 - accuracy: 0.1950 - val_loss: 1.7391 - val_accuracy: 0.2538
# Epoch 2/50
# 5/5 [==============================] - 0s 97ms/step - loss: 1.6726 - accuracy: 0.4286 - val_loss: 1.6350 - val_accuracy: 0.4923
# Epoch 3/50
# 5/5 [==============================] - 0s 97ms/step - loss: 1.5375 - accuracy: 0.4730 - val_loss: 1.5199 - val_accuracy: 0.4462
# Epoch 4/50
# 5/5 [==============================] - 0s 97ms/step - loss: 1.3994 - accuracy: 0.5598 - val_loss: 1.3743 - val_accuracy: 0.6154
# Epoch 5/50
# 5/5 [==============================] - 0s 86ms/step - loss: 1.2346 - accuracy: 0.6506 - val_loss: 1.3899 - val_accuracy: 0.4923
# Epoch 6/50
# 5/5 [==============================] - 0s 88ms/step - loss: 1.2300 - accuracy: 0.5753 - val_loss: 1.2102 - val_accuracy: 0.6308
# Epoch 7/50
# 5/5 [==============================] - 0s 85ms/step - loss: 1.1266 - accuracy: 0.6467 - val_loss: 1.1481 - val_accuracy: 0.6462
# Epoch 8/50
# 5/5 [==============================] - 0s 86ms/step - loss: 1.0197 - accuracy: 0.6274 - val_loss: 1.0764 - val_accuracy: 0.6538
# Epoch 9/50
# 5/5 [==============================] - 0s 101ms/step - loss: 0.9420 - accuracy: 0.7027 - val_loss: 1.0248 - val_accuracy: 0.7154
# Epoch 10/50
# 5/5 [==============================] - 1s 116ms/step - loss: 0.8017 - accuracy: 0.7799 - val_loss: 0.9141 - val_accuracy: 0.7077
# Epoch 11/50
# 5/5 [==============================] - 1s 113ms/step - loss: 0.7292 - accuracy: 0.7722 - val_loss: 0.8335 - val_accuracy: 0.7538
# Epoch 12/50
# 5/5 [==============================] - 1s 131ms/step - loss: 0.6610 - accuracy: 0.7896 - val_loss: 0.8688 - val_accuracy: 0.6846
# Epoch 13/50
# 5/5 [==============================] - 1s 130ms/step - loss: 0.6477 - accuracy: 0.7876 - val_loss: 0.9163 - val_accuracy: 0.6615
# Epoch 14/50
# 5/5 [==============================] - 1s 122ms/step - loss: 0.6426 - accuracy: 0.7625 - val_loss: 0.6700 - val_accuracy: 0.7769
# Epoch 15/50
# 5/5 [==============================] - 1s 157ms/step - loss: 0.4951 - accuracy: 0.8359 - val_loss: 0.6769 - val_accuracy: 0.7923
# Epoch 16/50
# 5/5 [==============================] - 1s 104ms/step - loss: 0.4476 - accuracy: 0.8610 - val_loss: 0.6458 - val_accuracy: 0.7923
# Epoch 17/50
# 5/5 [==============================] - 0s 86ms/step - loss: 0.4064 - accuracy: 0.8919 - val_loss: 0.6197 - val_accuracy: 0.7769
# Epoch 18/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.3681 - accuracy: 0.8880 - val_loss: 0.5600 - val_accuracy: 0.8077
# Epoch 19/50
# 5/5 [==============================] - 0s 102ms/step - loss: 0.3660 - accuracy: 0.8764 - val_loss: 0.5785 - val_accuracy: 0.7923
# Epoch 20/50
# 5/5 [==============================] - 0s 87ms/step - loss: 0.3989 - accuracy: 0.8649 - val_loss: 0.6515 - val_accuracy: 0.7692
# Epoch 21/50
# 5/5 [==============================] - 0s 87ms/step - loss: 0.3364 - accuracy: 0.8880 - val_loss: 0.5946 - val_accuracy: 0.7615
# Epoch 22/50
# 5/5 [==============================] - 0s 102ms/step - loss: 0.2778 - accuracy: 0.9073 - val_loss: 0.4898 - val_accuracy: 0.8077
# Epoch 23/50
# 5/5 [==============================] - 0s 87ms/step - loss: 0.2553 - accuracy: 0.9247 - val_loss: 0.5001 - val_accuracy: 0.8308
# Epoch 24/50
# 5/5 [==============================] - 0s 86ms/step - loss: 0.2387 - accuracy: 0.9266 - val_loss: 0.4766 - val_accuracy: 0.8308
# Epoch 25/50
# 5/5 [==============================] - 0s 88ms/step - loss: 0.2585 - accuracy: 0.9151 - val_loss: 0.5127 - val_accuracy: 0.8308
# Epoch 26/50
# 5/5 [==============================] - 0s 90ms/step - loss: 0.2194 - accuracy: 0.9382 - val_loss: 0.5433 - val_accuracy: 0.7769
# Epoch 27/50
# 5/5 [==============================] - 0s 102ms/step - loss: 0.2158 - accuracy: 0.9247 - val_loss: 0.4591 - val_accuracy: 0.8154
# Epoch 28/50
# 5/5 [==============================] - 0s 88ms/step - loss: 0.1519 - accuracy: 0.9730 - val_loss: 0.4661 - val_accuracy: 0.8231
# Epoch 29/50
# 5/5 [==============================] - 0s 99ms/step - loss: 0.2361 - accuracy: 0.9286 - val_loss: 0.4501 - val_accuracy: 0.8231
# Epoch 30/50
# 5/5 [==============================] - 0s 85ms/step - loss: 0.1697 - accuracy: 0.9537 - val_loss: 0.5602 - val_accuracy: 0.8000
# Epoch 31/50
# 5/5 [==============================] - 0s 98ms/step - loss: 0.1735 - accuracy: 0.9402 - val_loss: 0.5253 - val_accuracy: 0.8000
# Epoch 32/50
# 5/5 [==============================] - 0s 88ms/step - loss: 0.1510 - accuracy: 0.9595 - val_loss: 0.4827 - val_accuracy: 0.8000
# Epoch 33/50
# 5/5 [==============================] - 0s 90ms/step - loss: 0.1550 - accuracy: 0.9633 - val_loss: 0.4888 - val_accuracy: 0.8154
# Epoch 34/50
# 5/5 [==============================] - 0s 84ms/step - loss: 0.1195 - accuracy: 0.9768 - val_loss: 0.4529 - val_accuracy: 0.8154
# Epoch 35/50
# 5/5 [==============================] - 0s 85ms/step - loss: 0.1126 - accuracy: 0.9749 - val_loss: 0.5560 - val_accuracy: 0.8077
# Epoch 36/50
# 5/5 [==============================] - 0s 86ms/step - loss: 0.1168 - accuracy: 0.9672 - val_loss: 0.4832 - val_accuracy: 0.8000
# Epoch 37/50
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0898 - accuracy: 0.9788 - val_loss: 0.4720 - val_accuracy: 0.8385
# Epoch 38/50
# 5/5 [==============================] - 0s 99ms/step - loss: 0.0868 - accuracy: 0.9807 - val_loss: 0.4562 - val_accuracy: 0.8154
# Epoch 39/50
# 5/5 [==============================] - 0s 98ms/step - loss: 0.1073 - accuracy: 0.9749 - val_loss: 0.4984 - val_accuracy: 0.7923
# Epoch 40/50
# 5/5 [==============================] - 1s 159ms/step - loss: 0.0932 - accuracy: 0.9730 - val_loss: 0.5714 - val_accuracy: 0.8154
# Epoch 41/50
# 5/5 [==============================] - 1s 120ms/step - loss: 0.1232 - accuracy: 0.9595 - val_loss: 0.4751 - val_accuracy: 0.8000
# Epoch 42/50
# 5/5 [==============================] - 1s 129ms/step - loss: 0.0879 - accuracy: 0.9846 - val_loss: 0.5468 - val_accuracy: 0.8231
# Epoch 43/50
# 5/5 [==============================] - 1s 125ms/step - loss: 0.1009 - accuracy: 0.9749 - val_loss: 0.5214 - val_accuracy: 0.8154
# Epoch 44/50
# 5/5 [==============================] - 1s 127ms/step - loss: 0.0711 - accuracy: 0.9826 - val_loss: 0.4186 - val_accuracy: 0.8308
# Epoch 45/50
# 5/5 [==============================] - 1s 124ms/step - loss: 0.0565 - accuracy: 0.9961 - val_loss: 0.4073 - val_accuracy: 0.8231
# Epoch 46/50
# 5/5 [==============================] - 0s 99ms/step - loss: 0.0562 - accuracy: 0.9903 - val_loss: 0.4256 - val_accuracy: 0.8385
# Epoch 47/50
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0462 - accuracy: 0.9981 - val_loss: 0.4790 - val_accuracy: 0.8538
# Epoch 48/50
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0480 - accuracy: 0.9961 - val_loss: 0.4656 - val_accuracy: 0.8538
# Epoch 49/50
# 5/5 [==============================] - 0s 98ms/step - loss: 0.0389 - accuracy: 0.9981 - val_loss: 0.4320 - val_accuracy: 0.8385
# Epoch 50/50
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0345 - accuracy: 1.0000 - val_loss: 0.4373 - val_accuracy: 0.8538

# %% [markdown]
# Fitting the model with the data and finding out the accuracy at each epoch to see how our model is learning. Now we will train our model on 50 epochs and a batch size of 128. You can try using more number of epochs to increase accuracy but here we can see that the model has already reached a very high accuracy so we don't need to run it for more. During each epochs we can see how the model is performing by viewing the training and validation accuracy.

# %%
# Saving model
model.save("/content/drive/My Drive/bird_species.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# Now we will save the model in h5 format to use it later for prediction.

# %%
#Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# Next we will plot the accuracy of the model for the training history.

# %%
#Plot the loss history
plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], color='r')
plt.plot(history.history['val_loss'], color='b')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# Here we will plot the loss of the model for the training history.

# %%
# Calculating test accuracy
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# 6/6 [==============================] - 1s 31ms/step - loss: 0.5828 - accuracy: 0.8405
# Test Accuracy: 84.04908180236816

# %% [markdown]
# Evaluating the model to know the accuracy of the model on the test data.

# %%
# Storing predictions
y_pred = model.predict(x_test)
# Out:
# 6/6 [==============================] - 0s 11ms/step

# %% [markdown]
# Here we are storing prediction on test data.

# %%
# Plotting image to compare
img = array_to_img(x_test[5])
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %% [markdown]
# Visualizing one of the image which we will be further used for prediction.

# %%
# Finding max value from predition list and comaparing original value vs predicted
labels = lb.classes_
print(labels)
print("Originally : ",labels[np.argmax(y_test[5])])
print("Predicted : ",labels[np.argmax(y_pred[5])])
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER'
#  'EMPEROR PENGUIN' 'FLAMINGO']
# Originally :  BARN OWL
# Predicted :  BARN OWL

# %% [markdown]
# Now, we will create list of labels using object of label binarizer. We will print that list and finally we will print out the prediction and the original label of the image we visualized above using argmax().

# %% [markdown]
# # Conclusion:

# %% [markdown]
# We started with loading the dataset into google colab using google drive and visualizing the images. Normalizing is an important step when working with any type of dataset. After that we created a CNN Model which is further used for predicting the bird species using the image supplied to model.

# %% [markdown]
# # Scope:

# %% [markdown]
# This project can be used for educational purposes to get a better understanding of how to create network architecture for a CNN model. You can further hyper parameter tune this model to reach a higher accuracy. It can be used by bird sanctuaries to identify different types of birds.
